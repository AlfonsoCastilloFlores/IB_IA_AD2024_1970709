# %% [markdown]
# <a href="https://colab.research.google.com/github/AlfonsoCastilloFlores/IB_IA_AD2024_1970709/blob/main/FFNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# **Feedforward Neural Network Training on MNIST Dataset**
#[Alfonso De Jesus Castillo]
#1970709
#Thursday N3-N5

# %%
import numpy as np
import tensorflow as tf
from sklearn.neural_network import MLPClassifier
from tensorflow.keras.datasets import mnist
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
(train_data, train_labels), (test_data, test_labels) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
train_data = train_data.reshape((train_data.shape[0], 28 * 28))
test_data = test_data.reshape((test_data.shape[0], 28 * 28))

train_data, test_data = train_data / 255.0, test_data / 255.0

scaler = StandardScaler()
train_data = scaler.fit_transform(train_data)
test_data = scaler.transform(test_data)

# %%
model = MLPClassifier(hidden_layer_sizes=(128,), activation='relu', max_iter=5, solver='adam', random_state=42)
model.fit(train_data, train_labels)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (5) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(hidden_layer_sizes=(128,), max_iter=5, random_state=42)

# %%
test_predictions = model.predict(test_data)
test_accuracy = accuracy_score(test_labels, test_predictions)

print(f"Precisión en el conjunto de prueba: {test_accuracy * 100:.2f}%")
# Out:
# Precisión en el conjunto de prueba: 97.30%

# %%
for i in range(5):
    prediction = model.predict([test_data[i]])
    actual_label = test_labels[i]
    print(f"Predicción: {prediction[0]}, Real: {actual_label}")
# Out:
# Predicción: 7, Real: 7
# Predicción: 2, Real: 2
# Predicción: 1, Real: 1
# Predicción: 0, Real: 0
# Predicción: 4, Real: 4
